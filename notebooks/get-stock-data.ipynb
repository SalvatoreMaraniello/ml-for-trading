# %% [markdown]
# # Download Stock data
#
# ### Resources:
# - https://www.geeksforgeeks.org/how-to-download-historical-stock-prices-in-python/
# - https://pandas-datareader.readthedocs.io/en/latest/remote_data.html

# %% [markdown]
# ## Yahoo

# %%
# import modules 
from datetime import datetime, timedelta
import yfinance as yf 
import matplotlib.pyplot as plt 
  
# initialize parameters 
end_date = datetime.today()
start_date = end_date - timedelta(days=365*4+1)
  
# get the data 
data = yf.download('SPY', start = start_date,  end = end_date) 
display(data.head(3))
  
# display 
plt.figure(figsize = (10,4)) 
plt.title(f'Close Prices from {start_date:%d/%m/%Y} to {end_date:%d/%m/%Y}') 
plt.plot(data['Close']) 
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-03-04  306.119995  313.100006  303.329987  312.859985  293.780884
# 2020-03-05  304.980011  308.470001  300.010010  302.459991  284.015076
# 2020-03-06  293.149994  298.779999  290.230011  297.459991  279.320007
#
#                Volume
# Date
# 2020-03-04  176613400
# 2020-03-05  186366800
# 2020-03-06  228667200

# %% [markdown]
# ## Pandas Datareader
# This can access a number of backends - full list [here](https://pandas-datareader.readthedocs.io/en/latest/remote_data.html) or [official github repo](https://github.com/pydata/pandas-datareader/tree/main).
#
# **Warning: Yahoo API does not seem to work. Other data sources require API key.**

# %%
# import modules 
from datetime import datetime, timedelta
import pandas_datareader as pdr
import pandas_datareader.data as web

import matplotlib.pyplot as plt 
  
# initialize parameters 
end_date = datetime.today()
start_date = end_date - timedelta(days=20+1)
  
# Yahoo API not working
# data = web.DataReader(name="SPY", data_source="yahoo", start=start_date, end=end_date) 
# data = web.get_data_yahoo(["SPY"], start=start_date, end=end_date) 

data = pdr.get_data_fred('GS10')
data.head(3)
# Out:
#             GS10
# DATE
# 2019-04-01  2.53
# 2019-05-01  2.40
# 2019-06-01  2.07
